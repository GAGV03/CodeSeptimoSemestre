# %% [markdown]
# Revisión 2022AD

# %% [markdown]
# #Connect To Google drive

# %% [markdown]
# # Load Dataset
#
# dataframe (df) is the object where pandas stores the data, each colum is actualy a hash containing the name of the column a as a key and the array of values as the value for the key

# %%
import pandas as pd # type: ignore

# The file has no names for columns.
columns = ["sepalo length","sepal width","petal length","petal width", "class"]
df = pd.read_csv('iris.data',names = columns)
df
# Out:
#      sepalo length  sepal width  petal length  petal width           class
# 0              5.1          3.5           1.4          0.2     Iris-setosa
# 1              4.9          3.0           1.4          0.2     Iris-setosa
# 2              4.7          3.2           1.3          0.2     Iris-setosa
# 3              4.6          3.1           1.5          0.2     Iris-setosa
# 4              5.0          3.6           1.4          0.2     Iris-setosa
# ..             ...          ...           ...          ...             ...
# 145            6.7          3.0           5.2          2.3  Iris-virginica
# 146            6.3          2.5           5.0          1.9  Iris-virginica
# 147            6.5          3.0           5.2          2.0  Iris-virginica
# 148            6.2          3.4           5.4          2.3  Iris-virginica
# 149            5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.columns
# Out:
# Index(['sepalo length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %% [markdown]
# get a single column you wish

# %%
df["sepalo length"]
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepalo length, Length: 150, dtype: float64

# %% [markdown]
# get many columns

# %%
df[["sepalo length","sepal width"]].head()
# Out:
#    sepalo length  sepal width
# 0            5.1          3.5
# 1            4.9          3.0
# 2            4.7          3.2
# 3            4.6          3.1
# 4            5.0          3.6

# %%
df_x = df[["sepalo length","sepal width","petal length","petal width"]]
df_y = df[["class"]]

# %%
df_x.head()
# Out:
#    sepalo length  sepal width  petal length  petal width
# 0            5.1          3.5           1.4          0.2
# 1            4.9          3.0           1.4          0.2
# 2            4.7          3.2           1.3          0.2
# 3            4.6          3.1           1.5          0.2
# 4            5.0          3.6           1.4          0.2

# %%
df_y.head()
# Out:
#          class
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %% [markdown]
# make new columns with indicators

# %%
df_x["sepal proportion"] = df_x["sepal width"]/df_x["sepalo length"]
df_x["petal proportion"] = df_x["petal width"]/df_x["petal length"]
df_x.head()
# Out:
#    sepalo length  sepal width  petal length  petal width  sepal proportion  \
# 0            5.1          3.5           1.4          0.2          0.686275
# 1            4.9          3.0           1.4          0.2          0.612245
# 2            4.7          3.2           1.3          0.2          0.680851
# 3            4.6          3.1           1.5          0.2          0.673913
# 4            5.0          3.6           1.4          0.2          0.720000
#
#    petal proportion
# 0          0.142857
# 1          0.142857
# 2          0.153846
# 3          0.133333
# 4          0.142857

# %% [markdown]
# is the petal proportion less than 0.15?

# %%
df_x["petal proportion"] < 0.15
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: petal proportion, Length: 150, dtype: bool

# %% [markdown]
# which instances have a sepal length > 7?

# %%
df_x[df_x["sepalo length"] > 7]
# Out:
#      sepalo length  sepal width  petal length  petal width  sepal proportion  \
# 102            7.1          3.0           5.9          2.1          0.422535
# 105            7.6          3.0           6.6          2.1          0.394737
# 107            7.3          2.9           6.3          1.8          0.397260
# 109            7.2          3.6           6.1          2.5          0.500000
# 117            7.7          3.8           6.7          2.2          0.493506
# 118            7.7          2.6           6.9          2.3          0.337662
# 122            7.7          2.8           6.7          2.0          0.363636
# 125            7.2          3.2           6.0          1.8          0.444444
# 129            7.2          3.0           5.8          1.6          0.416667
# 130            7.4          2.8           6.1          1.9          0.378378
# 131            7.9          3.8           6.4          2.0          0.481013
# ...
