# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# # Limpieza de Datos

# %% [markdown]
# ## Datos Faltantes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
import missingno as msno  # type: ignore

# %%
# Visualize missing values as a matrix 
msno.bar(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Visualize missing values as a matrix
# ----> 2 msno.bar(df)
#
# File ~/miniconda3/envs/Ambiente-Conda/lib/python3.12/site-packages/missingno/missingno.py:266, in bar(df, figsize, fontsize, labels, log, color, inline, filter, n, p, sort, ax)
#     264 ax3.set_xticks(ax1.get_xticks())
#     265 ax3.set_xlim(ax1.get_xlim())
# --> 266 ax3.set_xticklabels(nullity_counts.values, fontsize=fontsize, rotation=45, ha='left')
#     267 ax3.grid(False)
#     269 for ax in axes:
#
# File ~/miniconda3/envs/Ambiente-Conda/lib/python3.12/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
nan_cols = df.isnull().sum()
nan_cols.loc[nan_cols != 0]
# Out:
# LotFrontage      259
# Alley           1369
# MasVnrType       872
# MasVnrArea         8
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Electrical         1
# FireplaceQu      690
# GarageType        81
# GarageYrBlt       81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PoolQC          1453
# Fence           1179
# MiscFeature     1406
# dtype: int64

# %% [markdown]
# ### Datos Faltantes
# Dado que hay atributos faltantes, debes hacer un análisis de qué paso con esas columnas. En equipo discultan lo que pueden observar sobre los datos.
#
# Considera:
# *   ¿El valor faltante es porque es imposible de existir o no fué registrado?
# *   Tiene sentido que "rellenemos" con un valor definido o dejarlo como categoría "Ninguno"
# *   ¿Borramos las instancias faltantes?
# *   ¿Borramos la columna?

# %%
#housing["LotFrontage"].fillna("Ninguno", inplace=True) #opcion 1
#df.housing["LotFrontage"].fillna(0, inplace=True) #opcion 2
#df.dropna(subset=["Electrical"])     # opcion 3
#df.drop("tAlley", axis=1)        # opcion 4

# %% [markdown]
# ### Separar Train, Validation, Test

# %%
from sklearn.model_selection import train_test_split # type: ignore

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df.drop(columns=["Id"]),
    df["SalePrice"],
    test_size=0.2,
    random_state=42)

# %%
x_train.shape
# Out:
# (1168, 80)

# %%
x_test.shape
# Out:
# (292, 80)

# %% [markdown]
# ### Separar Datos categoricos de numéricos

# %%
df.shape
# Out:
# (1460, 81)

# %%
x_num = x_train.select_dtypes(include=["int64","float64"])
x_num.shape
# Out:
# (1168, 37)

# %%
#df_num.drop(columns=["Id",],inplace=True)

# %%
# Visualize missing values as a matrix 
msno.bar(x_num)
# Out:
# <Axes: >

# %%
x_num.head()
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 254           20         70.0     8400            5            6       1957
# 1066          60         59.0     7837            6            7       1993
# 638           30         67.0     8777            5            7       1910
# 799           50         60.0     7200            5            7       1937
# 380           50         50.0     5000            5            6       1924
#
#       YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  ...  WoodDeckSF  \
# 254           1957         0.0         922           0  ...         250
# 1066          1994         0.0           0           0  ...           0
# 638           1950         0.0           0           0  ...         328
# 799           1950       252.0         569           0  ...           0
# 380           1950         0.0         218           0  ...           0
#
# ...

# %%
x_cat = x_train.select_dtypes(include=["object"])
x_cat.shape
# Out:
# (1168, 43)

# %%
x_cat.head()
# Out:
#      MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 254        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1066       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 638        RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 799        RL   Pave   NaN      Reg         Lvl    AllPub    Corner       Gtl
# 380        RL   Pave  Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1  ... GarageType GarageFinish GarageQual  \
# 254         NAmes       Norm  ...     Attchd          RFn         TA
# 1066      Gilbert       Norm  ...     Attchd          RFn         TA
# 638       Edwards      Feedr  ...        NaN          NaN        NaN
# 799         SWISU      Feedr  ...     Detchd          Unf         TA
# 380         SWISU       Norm  ...     Detchd          Unf         TA
#
#      GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType SaleCondition
# ...

# %%
msno.matrix(x_cat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 msno.matrix(x_cat)
#
# File c:\Users\atorr\anaconda3\envs\ml_env\Lib\site-packages\missingno\missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File c:\Users\atorr\anaconda3\envs\ml_env\Lib\site-packages\matplotlib\axes\_base.py:3196, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3194 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3195 if axis in ['x', 'both']:
# -> 3196     self.xaxis.grid(visible, which=which, **kwargs)
#    3197 if axis in ['y', 'both']:
# ...

# %%
from pandas.plotting import scatter_matrix # type: ignore

# %%
scatter_matrix(x_num)
# Out:
# array([[<Axes: xlabel='Id', ylabel='Id'>,
#         <Axes: xlabel='MSSubClass', ylabel='Id'>,
#         <Axes: xlabel='LotFrontage', ylabel='Id'>, ...,
#         <Axes: xlabel='MoSold', ylabel='Id'>,
#         <Axes: xlabel='YrSold', ylabel='Id'>,
#         <Axes: xlabel='SalePrice', ylabel='Id'>],
#        [<Axes: xlabel='Id', ylabel='MSSubClass'>,
#         <Axes: xlabel='MSSubClass', ylabel='MSSubClass'>,
#         <Axes: xlabel='LotFrontage', ylabel='MSSubClass'>, ...,
#         <Axes: xlabel='MoSold', ylabel='MSSubClass'>,
#         <Axes: xlabel='YrSold', ylabel='MSSubClass'>,
#         <Axes: xlabel='SalePrice', ylabel='MSSubClass'>],
#        [<Axes: xlabel='Id', ylabel='LotFrontage'>,
#         <Axes: xlabel='MSSubClass', ylabel='LotFrontage'>,
#         <Axes: xlabel='LotFrontage', ylabel='LotFrontage'>, ...,
#         <Axes: xlabel='MoSold', ylabel='LotFrontage'>,
#         <Axes: xlabel='YrSold', ylabel='LotFrontage'>,
# ...

# %%
import matplotlib.pyplot as plt # type: ignore

# %%
fig, ax = plt.subplots(figsize=(15,20))
x_num.hist(ax=ax)
plt.show()
# Out:
# C:\Users\atorr\AppData\Local\Temp\ipykernel_9284\911497185.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   x_num.hist(ax=ax)

# %% [markdown]
# ### Veamos correlaciones

# %%
matriz_correlacion = x_num.corr()
matriz_correlacion
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.371269 -0.116501     0.029719    -0.052768
# LotFrontage     -0.371269     1.000000  0.427009     0.249726    -0.051725
# LotArea         -0.116501     0.427009  1.000000     0.102088     0.001625
# OverallQual      0.029719     0.249726  0.102088     1.000000    -0.087599
# OverallCond     -0.052768    -0.051725  0.001625    -0.087599     1.000000
# YearBuilt       -0.001928     0.123858  0.013541     0.558124    -0.386268
# YearRemodAdd     0.036081     0.091253  0.017216     0.538251     0.055034
# MasVnrArea      -0.013491     0.223236  0.125634     0.416085    -0.143063
# BsmtFinSF1      -0.080944     0.236182  0.224270     0.204864    -0.043388
# BsmtFinSF2      -0.074205     0.065393  0.122366    -0.050637     0.047532
# BsmtUnfSF       -0.131854     0.126045 -0.014815     0.330061    -0.141671
# ...

# %%
matriz_correlacion = x_num.corr()

umbral = 0.7

alto_umbral = []

for col in matriz_correlacion.columns:
    correlated_cols = matriz_correlacion.index[matriz_correlacion[col] >= umbral].tolist()
    correlated_cols.remove(col)
    for correlated_col in correlated_cols:
        pair = (col, correlated_col)
        alto_umbral.append(pair)

print(alto_umbral)
# Out:
# [('OverallQual', 'SalePrice'), ('YearBuilt', 'GarageYrBlt'), ('TotalBsmtSF', '1stFlrSF'), ('1stFlrSF', 'TotalBsmtSF'), ('GrLivArea', 'TotRmsAbvGrd'), ('TotRmsAbvGrd', 'GrLivArea'), ('GarageYrBlt', 'YearBuilt'), ('GarageCars', 'GarageArea'), ('GarageArea', 'GarageCars'), ('SalePrice', 'OverallQual')]

# %% [markdown]
# ### ¿Qué hacer con Datos de correlacion alta?
#
# * Atributos altamente correlacionados pueden introducir redundancia en el modelo. Puedes eliminar alguna de ellas.
# * Quedate con aquella que tiene mayor correlacion con la variable de interés
# * Para después, aplicar PCA
# * Prueba como hiperparámetro en proceso de validacion
# * Decide que hacer con estas variables con tu equipo y justifica tu respuesta

# %%
column_of_interest = 'LotFrontage'

# Correlaciones entre la columna de interés y las demás columnas
correlations = x_num.corrwith(x_num[column_of_interest])

# Umbral para correlación alta (por ejemplo, 0.7)
threshold = 0.4

# Encontrar columnas con correlaciones altas con la columna de interés
high_corr_columns = correlations[correlations > threshold]

print("Columnas con correlación alta con", column_of_interest, ":", high_corr_columns)
# Out:
# Columnas con correlación alta con LotFrontage : LotFrontage    1.000000
# LotArea        0.427009
# 1stFlrSF       0.450932
# dtype: float64

# %%
import seaborn as sns # type: ignore

# %%
top_positive_corr = matriz_correlacion['SalePrice'].sort_values(ascending=False).head(15).index
top_negative_corr = matriz_correlacion['SalePrice'].sort_values(ascending=True).head(10).index
selected_columns = list(top_positive_corr) + list(top_negative_corr)
selected_data = x_num[selected_columns]
selected_corr_matrix = selected_data.corr()
plt.figure(figsize=(20, 16))
sns.heatmap(selected_corr_matrix, annot=True, cmap='coolwarm')
plt.title('Heatmap de las variables con mayor correlación con SalePrice')
plt.show()

# %% [markdown]
# ### Datos Faltantes
#
# Diferentes estrategias para manejar datos faltantes, elige una, justifica tu respuesta y aplica sobre dataset de entrenamiento.
#
# Piensa en hacer funciones para que puedas aplicar el mismo proceso para el conjunto de prueba
# **Pregunta: ¿Como manejar datos faltantes sobre el conjunto de pruba?

# %% [markdown]
# ### Rellenar datos numericos
#
# * Valor dependiendo del problema.
# * Media. Si vemos distribución simétrica y cuando tenemos muchos datos
# * Mediana. Distribuciones sesgadas, no afectada por valores atipicos, menor representatividad en datos simentricos
# * Moda: Distribuciones discretas. No datos continuos. Sirve para ubicar datos dominantes.

# %%
# Rellenar con un dato en específico
x_num['LotFrontage'] = x_num['LotFrontage'].fillna(0).astype(int)

# %%
#Rellenar con la moda o mediana o promedio
x_num["GarageYrBlt"] = x_num["GarageYrBlt"].fillna(x_num["GarageYrBlt"].median())

# %%
from sklearn.impute import SimpleImputer # type: ignore

# %%
x_num.columns
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
imputer_num = SimpleImputer(strategy='median')
median = imputer_num.fit_transform(x_train[x_num.columns])

imputer_mode = SimpleImputer(strategy='mode')
mode = imputer_mode.fit_transform(x_train[x_num.columns])

imputer_num_3 = SimpleImputer(strategy='mean')
mean = imputer_num_3.fit_transform(x_train[x_num.columns])

imputer_num_4 = SimpleImputer(strategy='constant', fill_value="Desconocido")
new_category = imputer_num_4.fit_transform(x_train[x_num.columns])

# %%
#Rellenar con la moda o mediana o promedio
df["variable"] = df["variable"].fillna(df["variable"].median())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/Ambiente-Conda/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variable'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 2
#       1 #Rellenar con la moda o mediana o promedio
# ...

# %% [markdown]
# ### Llenar datos faltantes para datos categoricos
# * Podemos rellenar con el dato específico segun el problema
# * Generar las siguientes estrategias:
#     *   Usa MODA, si una clase representa mas del 90% de los valores no nulos
#     * Usa Una Nueva Categoría si los datos faltantes son menos de 5% del total de datos y no hay clase dominante.
#     * Usar estrategia predictiva si la distribucion de las clases es equilibrada

# %%
from collections import Counter

# %%
class_counts = {}
missing_values = {}

for col in x_cat.columns:
    class_count = Counter(x_cat[col].dropna())  # Excluir valores faltantes al contar clases
    class_counts[col] = class_count
    missing_values[col] = x_cat[col].isnull().sum()

# %%
for col, counts in class_counts.items():
    print(f"\nColumna: {col}")
    print(f"Conteos de clases: {counts}")
    print(f"Valores faltantes: {missing_values[col]}")
# Out:
# Columna: MSZoning
# Conteos de clases: Counter({'RL': 924, 'RM': 172, 'FV': 53, 'RH': 15, 'C (all)': 4})
# Valores faltantes: 0
#
# Columna: Street
# Conteos de clases: Counter({'Pave': 1164, 'Grvl': 4})
# Valores faltantes: 0
#
# Columna: Alley
# Conteos de clases: Counter({'Grvl': 44, 'Pave': 30})
# Valores faltantes: 1094
#
# Columna: LotShape
# Conteos de clases: Counter({'Reg': 729, 'IR1': 394, 'IR2': 37, 'IR3': 8})
# Valores faltantes: 0
#
# Columna: LandContour
# Conteos de clases: Counter({'Lvl': 1059, 'Bnk': 48, 'HLS': 35, 'Low': 26})
# Valores faltantes: 0
#
# Columna: Utilities
# Conteos de clases: Counter({'AllPub': 1167, 'NoSeWa': 1})
# Valores faltantes: 0
#
# Columna: LotConfig
# Conteos de clases: Counter({'Inside': 822, 'Corner': 221, 'CulDSac': 84, 'FR2': 38, 'FR3': 3})
# Valores faltantes: 0
#
# Columna: LandSlope
# Conteos de clases: Counter({'Gtl': 1108, 'Mod': 51, 'Sev': 9})
# Valores faltantes: 0
#
# Columna: Neighborhood
# ...

# %%
imputer_mode = SimpleImputer(strategy='most_frequent')
imputer_new_category = SimpleImputer(strategy='constant', fill_value="Desconocido")

# %%
for col, counts in class_counts.items():
    most_common_class, most_common_count = counts.most_common(1)[0]
    total_non_null = sum(counts.values())
 
    
    print(f"\nSugerencia para la columna: {col}")
    
    # Si hay una clase muy dominante (e.g., >90% de los valores), sugiere imputar con la moda
    if most_common_count / total_non_null > 0.9:
        print(f"Sugiere imputar con la moda: '{most_common_class}'")
        mode = imputer_mode.fit_transform(x_train[[col]])
    
        
    # Si no hay una clase dominante pero hay pocos valores faltantes, sugiere crear una nueva categoría
    elif missing_values[col] / len(x_cat) < 0.05:
        print("Sugiere imputar creando una nueva categoría ('Desconocido' o 'Faltante').")
        new_category = imputer_new_category.fit_transform(x_train[[col]])
    
    # Si hay una distribución equilibrada entre varias clases, sugiere imputación predictiva
    else:
        print("Sugiere considerar una imputación predictiva o basada en KNN.")
# Out:
# Sugerencia para la columna: MSZoning
# Sugiere imputar creando una nueva categoría ('Desconocido' o 'Faltante').
#
# Sugerencia para la columna: Street
# Sugiere imputar con la moda: 'Pave'
#
# Sugerencia para la columna: Alley
# Sugiere considerar una imputación predictiva o basada en KNN.
#
# Sugerencia para la columna: LotShape
# Sugiere imputar creando una nueva categoría ('Desconocido' o 'Faltante').
#
# Sugerencia para la columna: LandContour
# Sugiere imputar con la moda: 'Lvl'
#
# Sugerencia para la columna: Utilities
# Sugiere imputar con la moda: 'AllPub'
#
# Sugerencia para la columna: LotConfig
# Sugiere imputar creando una nueva categoría ('Desconocido' o 'Faltante').
#
# Sugerencia para la columna: LandSlope
# Sugiere imputar con la moda: 'Gtl'
#
# Sugerencia para la columna: Neighborhood
# Sugiere imputar creando una nueva categoría ('Desconocido' o 'Faltante').
#
# Sugerencia para la columna: Condition1
# ...

# %% [markdown]
# ## En equipo llenen los datos faltantes siguiendo las estrategias para los datos faltantes numéricos y categóricos

# %%
x_num.shape
# Out:
# (1168, 37)

# %% [markdown]
# # Valores atípicos

# %%
fig, axes = plt.subplots(7, 6, figsize=(15, 5*7))

# Itera por cada columna y genera el boxplot
for i, col in enumerate(x_num.columns):
    row = i // 6
    col_idx = i % 6
    x_num[col].plot(kind='box', ax=axes[row, col_idx])
    axes[row, col_idx].set_title(col)

# Ajusta el espacio entre los subplots
plt.subplots_adjust(wspace=0.5, hspace=0.5)

# Muestra la figura
plt.show()

# %% [markdown]
# ### ¿Qué hacer con datos atípicos?
# * Puedes eliminarlos si claramente es un error, pero puedes perder información y ayuda a eliminar ruido, pero (¿qué tal y se trata de una compra inusualmente grande, como un cliente clave?)
# * Transformar los Datos
#     * Logaritmicas. Util cuando tenemos distribuciones asimétricas
# * Reemplazo de esos valores atípicos
#     * Reemplaza con el 95% o 5%
#     * Limita los valores a un rango específico
# * Usa algoritmos menos sensibles a outliers. Los árboles de decisión o Random Forest y XGBoost, son algortimos menos sensibles a outliers en comparación con SVM y Regresion Lineal.
# * Categorización o Binning. Si tienes Rangos amplios describe datos en "Clases numéricas".

# %% [markdown]
# #### Estrategia Recomendada
#
#
#     * Eliminación de Outliers: Útil cuando los outliers son claramente errores o anomalías sin valor analítico.
#     * Transformación de Datos: Recomendada para datos con distribuciones sesgadas o cuando se busca cumplir con supuestos de normalidad.
#     * Imputación de Outliers: Ideal cuando los outliers no son errores, pero se desea limitar su influencia en el análisis.
#     * Modelos Robustos: Utilizar si los outliers son comunes o si se sospecha que pueden contener información valiosa.
#     * Categorización: Considerar en situaciones donde la simplicidad y la reducción de la variabilidad son prioritarias.

# %% [markdown]
# # En equipo determina la estrategia que usarás para tratar valores atípicos

# %% [markdown]
# # Transformacion de Datos numéricos

# %% [markdown]
# # Normalizar y transformar Datos categoricos
#
# Para este paso suponemos que hemos llenado datos faltantes.
# * Si vamos a usar algorimos que asumen que los datos están centrados y escalados y basados en distancias como: KNN, SVM, Regresion Lineal. USA ESTANDARIZACION
#
# *

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[['columna_numerica']])

# %% [markdown]
# * Normalización: Datos que van en un rango, generalmente entre 0 y 1. Usa esta estrategia si, usaras redes neuronales o si los datos tienen un rango conocido.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df_normalized = scaler.fit_transform(df[['columna_numerica']])

# %% [markdown]
# * Robust Scaling: Ideal cuando los outliers no han sido completamente tratados y podrían afectar a los métodos de escalado estándar. Búscalo en la documentacion de sklearn

# %% [markdown]
# # Transforma los datos numéricos, elige una estrategia

# %% [markdown]
# # Tratamiento de datos categóricos
# * One-Hot Encoding. Variables sin un orden inherente

# %%
import pandas as pd

df = pd.get_dummies(df, columns=['columna_categorica'], drop_first=True)

# %% [markdown]
#  * Label Encoding: Asigna un valor numérico único a cada categoría de la variable.
#
# Cuándo usarla  si las categorías tienen un orden natural (e.g., bajo, medio, alto). y con algoritmos como árboles de decisión o random forest

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['columna_categorica_codificada'] = encoder.fit_transform(df['columna_categorica'])

# %% [markdown]
# # Determina una estrategia y conviete tus datos categoricos

# %% [markdown]
# Combina tus datos en el dataframe final y genera un pipeline que haga las mismas trasformaciones sobre tus datos de prueba. N4
